# %% [markdown]
# # Melakukan import library dan ekspor dataset

# %%
import pandas as pd

# %%
file_path = "/content/mental_health_finaldata_1.csv"
df = pd.read_csv(file_path)

# %% [markdown]
# # Data Understanding

# %% [markdown]
#  Sumber data [Depression and Mental Health](https://www.kaggle.com/datasets/shashwatwork/depression-and-mental-health-data-analysis/data)

# %% [markdown]
# Menampilkan dataset.

# %%
df
# Out:
#           Age  Gender Occupation        Days_Indoors Growing_Stress  \
# 0       20-25  Female  Corporate           1-14 days            Yes
# 1    30-Above    Male     Others          31-60 days            Yes
# 2    30-Above  Female    Student    Go out Every day             No
# 3       25-30    Male     Others           1-14 days            Yes
# 4       16-20  Female    Student  More than 2 months            Yes
# ..        ...     ...        ...                 ...            ...
# 819     20-25    Male  Corporate    Go out Every day             No
# 820     20-25    Male     Others           1-14 days            Yes
# 821     20-25    Male    Student  More than 2 months            Yes
# 822     16-20    Male   Business          15-30 days             No
# 823  30-Above  Female     Others          15-30 days             No
#
#     Quarantine_Frustrations Changes_Habits Mental_Health_History  \
# 0                       Yes             No                   Yes
# ...

# %% [markdown]
# Menampilkan informasi dari dataset.

# %%
df.info()
# Out:
# Menampilkan informasi dari dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      824 non-null    object
#  1   Gender                   824 non-null    object
#  2   Occupation               824 non-null    object
#  3   Days_Indoors             824 non-null    object
#  4   Growing_Stress           824 non-null    object
#  5   Quarantine_Frustrations  824 non-null    object
#  6   Changes_Habits           824 non-null    object
#  7   Mental_Health_History    824 non-null    object
#  8   Weight_Change            824 non-null    object
#  9   Mood_Swings              824 non-null    object
#  10  Coping_Struggles         824 non-null    object
#  11  Work_Interest            824 non-null    object
#  12  Social_Weakness          824 non-null    object
# dtypes: object(13)
# ...

# %% [markdown]
# Menampilkan jumlah baris dan kolom dari dataset.

# %%
df.shape
# Out:
# Menampilkan jumlah baris dan kolom dari dataset:
# (824, 13)

# %% [markdown]
# Menampilkan tipe data dari setiap kolom dalam dataeset.

# %%
df.dtypes
# Out:
# Age                        object
# Gender                     object
# Occupation                 object
# Days_Indoors               object
# Growing_Stress             object
# Quarantine_Frustrations    object
# Changes_Habits             object
# Mental_Health_History      object
# Weight_Change              object
# Mood_Swings                object
# Coping_Struggles           object
# Work_Interest              object
# Social_Weakness            object
# dtype: object

# %% [markdown]
# Menampilkan statistik deskriptif dari dataset.

# %%
df.describe()
# Out:
#              Age  Gender Occupation Days_Indoors Growing_Stress  \
# count        824     824        824          824            824
# unique         4       2          5            5              3
# top     30-Above  Female  Housewife   31-60 days            Yes
# freq         222     434        185          171            301
#
#        Quarantine_Frustrations Changes_Habits Mental_Health_History  \
# count                      824            824                   824
# unique                       3              3                     3
# top                        Yes            Yes                    No
# freq                       304            305                   284
#
#        Weight_Change Mood_Swings Coping_Struggles Work_Interest  \
# count            824         824              824           824
# unique             3           3                2             3
# top            Maybe      Medium               No            No
# ...

# %% [markdown]
# Dataset ini bertipekan object dan bukan numerik. Jadi tidak bisa dilakukan pengecekan korelasi.

# %% [markdown]
# Menampilkan dan melakukan perhitungan dari setiap kemunculan nilai pada kolom.

# %%
hitung_kolom = [
    'Age', 'Gender', 'Occupation', 'Days_Indoors', 'Growing_Stress', 'Quarantine_Frustrations',
    'Changes_Habits', 'Mental_Health_History', 'Weight_Change',
    'Mood_Swings', 'Coping_Struggles', 'Work_Interest', 'Social_Weakness'
]

for col in hitung_kolom:
    print(f"\nPerhitungan jumlah kemunculan nilai masing-masing kolom: '{col}':")
    print(df[col].value_counts())
    print("-" * 50)
# Out:
# Perhitungan jumlah kemunculan nilai masing-masing kolom: 'Age':
# Age
# 30-Above    222
# 16-20       211
# 25-30       205
# 20-25       186
# Name: count, dtype: int64
# --------------------------------------------------
#
# Perhitungan jumlah kemunculan nilai masing-masing kolom: 'Gender':
# Gender
# Female    434
# Male      390
# Name: count, dtype: int64
# --------------------------------------------------
#
# Perhitungan jumlah kemunculan nilai masing-masing kolom: 'Occupation':
# Occupation
# Housewife    185
# Student      180
# Corporate    159
# Others       155
# Business     145
# Name: count, dtype: int64
# --------------------------------------------------
#
# Perhitungan jumlah kemunculan nilai masing-masing kolom: 'Days_Indoors':
# Days_Indoors
# 31-60 days            171
# 1-14 days             170
# Go out Every day      168
# More than 2 months    160
# 15-30 days            155
# Name: count, dtype: int64
# --------------------------------------------------
#
# ...

# %% [markdown]
# # Data Preparation

# %% [markdown]
#  Sumber data [Depression and Mental Health](https://www.kaggle.com/datasets/shashwatwork/depression-and-mental-health-data-analysis/data)

# %% [markdown]
# Melakukan pengecekan missing values dari dataset.

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Age                        0.0
# Gender                     0.0
# Occupation                 0.0
# Days_Indoors               0.0
# Growing_Stress             0.0
# Quarantine_Frustrations    0.0
# Changes_Habits             0.0
# Mental_Health_History      0.0
# Weight_Change              0.0
# Mood_Swings                0.0
# Coping_Struggles           0.0
# Work_Interest              0.0
# Social_Weakness            0.0
# dtype: float64

# %% [markdown]
# Melakukan pengecekan dataset apabila terindikasi adanya duplikat.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Occupation, Days_Indoors, Growing_Stress, Quarantine_Frustrations, Changes_Habits, Mental_Health_History, Weight_Change, Mood_Swings, Coping_Struggles, Work_Interest, Social_Weakness]
# Index: []

# %% [markdown]
# Dataset ini bertipekan object dan bukan numerik. Jadi tidak bisa dilakukan pengecekan nilai outliers.

# %% [markdown]
# Melakukan pengecekan incosistent values di setiap kolom jika terindikasi adanya nilai yang tidak sesuai kriteria.

# %%
hitung_kolom = [
    'Age', 'Gender', 'Occupation', 'Days_Indoors', 'Growing_Stress', 'Quarantine_Frustrations',
    'Changes_Habits', 'Mental_Health_History', 'Weight_Change',
    'Mood_Swings', 'Coping_Struggles', 'Work_Interest', 'Social_Weakness'
]

for col in hitung_kolom:
    print(f"\nPerhitungan jumlah kemunculan nilai masing-masing kolom: '{col}':")
    print(df[col].value_counts())
    print("-" * 50)
# Out:
# Perhitungan jumlah kemunculan nilai masing-masing kolom: 'Age':
# Age
# 30-Above    222
# 16-20       211
# 25-30       205
# 20-25       186
# Name: count, dtype: int64
# --------------------------------------------------
#
# Perhitungan jumlah kemunculan nilai masing-masing kolom: 'Gender':
# Gender
# Female    434
# Male      390
# Name: count, dtype: int64
# --------------------------------------------------
#
# Perhitungan jumlah kemunculan nilai masing-masing kolom: 'Occupation':
# Occupation
# Housewife    185
# Student      180
# Corporate    159
# Others       155
# Business     145
# Name: count, dtype: int64
# --------------------------------------------------
#
# Perhitungan jumlah kemunculan nilai masing-masing kolom: 'Days_Indoors':
# Days_Indoors
# 31-60 days            171
# 1-14 days             170
# Go out Every day      168
# More than 2 months    160
# 15-30 days            155
# Name: count, dtype: int64
# --------------------------------------------------
#
# ...

# %% [markdown]
# Melakukan construct data antara 'Age' dengan 'Gender' agar menjadi 'Age and Gender' dan melakukan data reduction untuk kolom yang dirasa tidak relevan.

# %%
df['Gender_and_Age'] = df['Gender'] + '-' + df['Age'].astype(str)

# %%
df
# Out:
#           Age  Gender Occupation        Days_Indoors Growing_Stress  \
# 0       20-25  Female  Corporate           1-14 days            Yes
# 1    30-Above    Male     Others          31-60 days            Yes
# 2    30-Above  Female    Student    Go out Every day             No
# 3       25-30    Male     Others           1-14 days            Yes
# 4       16-20  Female    Student  More than 2 months            Yes
# ..        ...     ...        ...                 ...            ...
# 819     20-25    Male  Corporate    Go out Every day             No
# 820     20-25    Male     Others           1-14 days            Yes
# 821     20-25    Male    Student  More than 2 months            Yes
# 822     16-20    Male   Business          15-30 days             No
# 823  30-Above  Female     Others          15-30 days             No
#
#     Quarantine_Frustrations Changes_Habits Mental_Health_History  \
# 0                       Yes             No                   Yes
# ...

# %%
df = df.drop('Gender', axis=1)

# %%
df = df.drop('Age', axis=1)

# %%
df = df.drop('Days_Indoors', axis=1)

# %%
df = df.drop('Changes_Habits', axis=1)

# %%
df = df.drop('Weight_Change', axis=1)

# %%
df = df.drop('Work_Interest', axis=1)

# %% [markdown]
# Melakukan pengecekan ulang pada dataset.

# %%
df
# Out:
#     Occupation Growing_Stress Quarantine_Frustrations Mental_Health_History  \
# 0    Corporate            Yes                     Yes                   Yes
# 1       Others            Yes                     Yes                    No
# 2      Student             No                      No                    No
# 3       Others            Yes                      No                    No
# 4      Student            Yes                     Yes                    No
# ..         ...            ...                     ...                   ...
# 819  Corporate             No                     Yes                   Yes
# 820     Others            Yes                     Yes                   Yes
# 821    Student            Yes                   Maybe                    No
# 822   Business             No                      No                    No
# 823     Others             No                      No                    No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Occupation               824 non-null    object
#  1   Growing_Stress           824 non-null    object
#  2   Quarantine_Frustrations  824 non-null    object
#  3   Mental_Health_History    824 non-null    object
#  4   Mood_Swings              824 non-null    object
#  5   Coping_Struggles         824 non-null    object
#  6   Social_Weakness          824 non-null    object
#  7   Gender_and_Age           824 non-null    object
# dtypes: object(8)
# memory usage: 51.6+ KB

# %% [markdown]
# Melakukan perhitungan ulang pada setiap kolom.

# %%
hitung_kolom = [
    'Gender_and_Age', 'Occupation', 'Growing_Stress', 'Quarantine_Frustrations',
    'Mental_Health_History', 'Mood_Swings', 'Coping_Struggles', 'Social_Weakness'
]

for col in hitung_kolom:
    print(f"\nPerhitungan jumlah kemunculan nilai masing-masing kolom: '{col}':")
    print(df[col].value_counts())
    print("-" * 50)
# Out:
# Perhitungan jumlah kemunculan nilai masing-masing kolom: 'Gender_and_Age':
# Gender_and_Age
# Female-30-Above    117
# Female-25-30       115
# Female-16-20       110
# Male-30-Above      105
# Male-16-20         101
# Male-20-25          94
# Female-20-25        92
# Male-25-30          90
# Name: count, dtype: int64
# --------------------------------------------------
#
# Perhitungan jumlah kemunculan nilai masing-masing kolom: 'Occupation':
# Occupation
# Housewife    185
# Student      180
# Corporate    159
# Others       155
# Business     145
# Name: count, dtype: int64
# --------------------------------------------------
#
# Perhitungan jumlah kemunculan nilai masing-masing kolom: 'Growing_Stress':
# Growing_Stress
# Yes      301
# Maybe    267
# No       256
# Name: count, dtype: int64
# --------------------------------------------------
#
# Perhitungan jumlah kemunculan nilai masing-masing kolom: 'Quarantine_Frustrations':
# Quarantine_Frustrations
# Yes      304
# ...
