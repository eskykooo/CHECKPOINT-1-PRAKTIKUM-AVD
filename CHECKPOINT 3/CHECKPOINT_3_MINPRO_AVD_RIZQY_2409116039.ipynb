# %% [markdown]
# # **MELAKUKAN IMPORT**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "/content/data_mental_fix.csv"
df = pd.read_csv(file_path)
df
# Out:
#     Occupation Growing_Stress Quarantine_Frustrations Mental_Health_History  \
# 0    Corporate            Yes                     Yes                   Yes
# 1       Others            Yes                     Yes                    No
# 2      Student             No                      No                    No
# 3       Others            Yes                      No                    No
# 4      Student            Yes                     Yes                    No
# ..         ...            ...                     ...                   ...
# 819  Corporate             No                     Yes                   Yes
# 820     Others            Yes                     Yes                   Yes
# 821    Student            Yes                   Maybe                    No
# 822   Business             No                      No                    No
# 823     Others             No                      No                    No
#
# ...

# %% [markdown]
# # **ANALISIS DAN VISUALISASI DATA**

# %% [markdown]
# ## DISTRIBUSI OCCUPATION

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="Occupation", data=df, hue="Occupation", legend=False, palette="muted")
plt.title("Distribusi Pekerjaan")
plt.xlabel("Jenis Pekerjaan")
plt.ylabel("Jumlah")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### INSIGHT

# %% [markdown]
# Terlihat bahwa kategori mahasiswa (student) dan ibu rumah tangga (housewife) memiliki jumlah tertinggi dibandingkan kategori lainnya. Hal ini menunjukkan bahwa kedua kelompok lebih sering mengalami permasalahan terkait kesehatan mental. Sebaliknya, kategori business memiliki jumlah terendah, yang dapat mengindikasikan bahwa individu di bidang bisnis kurang terwakili dalam data atau memiliki keterbatasan dalam mengakses layanan kesehatan mental.

# %% [markdown]
# ### TINDAKAN

# %% [markdown]
# Berdasarkan temuan ini, beberapa tindakan dapat diambil untuk meningkatkan kesadaran dan dukungan terhadap kesehatan mental. Pertama, mahasiswa dan ibu rumah tangga dapat menjadi fokus utama dalam penyediaan program dukungan, seperti layanan konseling atau pelatihan manajemen stres yang disesuaikan dengan tantangan mereka. Kedua, perlu ada upaya untuk meningkatkan aksesibilitas layanan kesehatan mental bagi pelaku bisnis, misalnya melalui kampanye edukasi atau penyediaan layanan fleksibel yang sesuai dengan jadwal mereka.

# %% [markdown]
# ## DISTRIBUSI GROWING STRESS

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="Growing_Stress", data=df, hue="Growing_Stress", legend=False, palette="muted")
plt.title("Distribusi Peningkatan Stres")
plt.xlabel("Peningkatan Stres")
plt.ylabel("Jumlah")
plt.show()

# %% [markdown]
# ### INSIGHT

# %% [markdown]
# Dari visualisasi distribusi peningkatan stres di atas, mayoritas responden mengaku mengalami peningkatan stres (Yes), sementara sebagian lainnya tidak mengalami peningkatan stres (No) atau merasa ragu-ragu (Maybe). Hal ini menunjukkan bahwa stres merupakan masalah yang signifikan bagi banyak individu, dengan sebagian besar responden menyadari adanya peningkatan tingkat stres dalam kehidupan mereka. Sementara itu, jumlah responden yang menjawab Maybe cukup tinggi, yang mungkin mengindikasikan kurangnya kesadaran atau pemahaman mereka terhadap gejala stres yang mereka alami.

# %% [markdown]
# ### TINDAKAN

# %% [markdown]
# Untuk mengatasi permasalahan ini, beberapa tindakan dapat dilakukan. Pertama, penting untuk meningkatkan kesadaran masyarakat mengenai tanda-tanda stres dan dampaknya terhadap kesehatan mental, misalnya melalui kampanye edukasi atau seminar kesehatan mental. Kedua, penyediaan akses ke layanan dukungan psikologis, seperti konseling atau terapi, dapat membantu mereka yang mengalami peningkatan stres agar dapat mengelola kondisi mereka dengan lebih baik.

# %% [markdown]
# ## DISTRIBUSI QUARANTINE FRUSTRATIONS

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Quarantine_Frustrations", data=df, hue="Quarantine_Frustrations", legend=False, palette="muted")
plt.title("Frustrasi Selama Karantina")
plt.xlabel("Apakah Merasa Frustrasi")
plt.ylabel("Jumlah")
plt.show()

# %% [markdown]
# ### INSIGHT

# %% [markdown]
# Berdasarkan visualisasi di atas, mayoritas responden mengaku mengalami frustrasi selama masa karantina (Yes), sementara sebagian lainnya tidak merasa frustrasi (No) atau merasa ragu-ragu (Maybe). Hal ini menunjukkan bahwa karantina berdampak signifikan terhadap kesehatan mental banyak individu, dengan tingkat frustrasi yang cukup tinggi. Sementara itu, kelompok Maybe yang cukup besar bisa mengindikasikan bahwa beberapa individu mengalami perasaan campur aduk atau kurang menyadari dampak psikologis dari situasi tersebut.

# %% [markdown]
# ### TINDAKAN

# %% [markdown]
# Untuk mengatasi masalah ini, beberapa langkah dapat diambil. Pertama, perlu adanya program dukungan psikologis selama masa karantina, seperti layanan konseling daring atau komunitas pendukung untuk membantu individu mengelola emosi mereka. Kedua, penting untuk mengedukasi masyarakat mengenai cara-cara mengatasi stres dan frustrasi selama masa isolasi, seperti menjaga rutinitas harian, berolahraga, atau tetap terhubung dengan keluarga dan teman melalui teknologi.

# %% [markdown]
# ## DISTRIBUSI MENTAL HEALTH HISTORY

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Mental_Health_History", data=df, hue="Mental_Health_History", legend=False, palette="muted")
plt.title("Riwayat Kesehatan Mental")
plt.xlabel("Apakah Memiliki Riwayat Penyakit Mental")
plt.ylabel("Jumlah")
plt.show()

# %% [markdown]
# ### INSIGHT

# %% [markdown]
# Berdasarkan visualisasi di atas, terdapat distribusi yang relatif seimbang antara responden yang memiliki riwayat penyakit mental (Yes), yang tidak memiliki (No), dan yang ragu-ragu (Maybe). Jumlah responden yang menjawab Maybe cukup tinggi, yang menunjukkan bahwa masih banyak individu yang tidak yakin atau kurang memiliki pemahaman yang jelas tentang kondisi kesehatan mental mereka. Hal ini bisa disebabkan oleh kurangnya kesadaran atau akses terhadap diagnosis profesional.

# %% [markdown]
# ### TINDAKAN

# %% [markdown]
# Beberapa tindakan yang dapat diambil untuk menanggapi temuan ini adalah meningkatkan edukasi mengenai kesehatan mental agar masyarakat lebih memahami gejala dan pentingnya diagnosis dini. Kampanye kesadaran melalui media sosial, seminar, atau lokakarya bisa membantu individu mengenali tanda-tanda gangguan mental yang mungkin mereka alami. Selain itu, menyediakan layanan konsultasi psikologis gratis atau terjangkau bisa membantu mereka yang merasa ragu-ragu untuk mendapatkan penilaian profesional.

# %% [markdown]
# ## DISTRIBUSI MOOD SWINGS

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Mood_Swings", data=df, hue="Mood_Swings", legend=False, palette="muted")
plt.title("Distribusi Mood Swings")
plt.xlabel("Tingkat Mood Swings")
plt.ylabel("Jumlah")
plt.show()

# %% [markdown]
# ### INSIGHT

# %% [markdown]
# Visualisasi menunjukkan distribusi tingkat mood swings di antara responden, dengan kategori Medium, High, dan Low yang memiliki jumlah yang relatif seimbang. Namun, terlihat bahwa mayoritas individu memiliki mood swings pada tingkat Medium dan Low, sementara jumlah responden dengan High mood swings juga cukup signifikan. Ini mengindikasikan bahwa fluktuasi suasana hati adalah fenomena yang cukup umum, tetapi sebagian individu mengalami perubahan suasana hati yang lebih ekstrem.

# %% [markdown]
# ### TINDAKAN

# %% [markdown]
# Untuk menanggapi temuan ini, penting untuk meningkatkan kesadaran akan faktor-faktor yang dapat mempengaruhi mood swings, seperti stres, pola tidur, pola makan, serta kondisi psikologis yang mendasarinya. Individu dengan High mood swings mungkin memerlukan dukungan lebih lanjut, baik melalui edukasi mengenai manajemen emosi maupun akses ke layanan kesehatan mental.

# %% [markdown]
# ## DISTRIBUSI COPING STRUGGLES

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Coping_Struggles", data=df, hue="Coping_Struggles", legend=False, palette="muted")
plt.title("Kesulitan Mengatasi Masalah")
plt.xlabel("Coping Struggles")
plt.ylabel("Jumlah")
plt.show()

# %% [markdown]
# ### INSIGHT

# %% [markdown]
# Grafik ini menunjukkan bahwa jumlah orang yang mengalami kesulitan mengatasi masalah hampir sama dengan mereka yang tidak mengalami kesulitan. Ini berarti bahwa setengah dari responden merasa kesulitan menghadapi tekanan dan tantangan dalam hidup mereka.

# %% [markdown]
# ### TINDAKAN

# %% [markdown]
# Melihat data ini, penting untuk meningkatkan kesadaran akan pentingnya kesehatan mental dan memberikan akses yang lebih luas ke layanan dukungan, seperti konseling atau terapi. Selain itu, orang-orang perlu dibekali dengan cara mengelola stres yang lebih baik, misalnya melalui olahraga, meditasi, atau kegiatan yang bisa membantu mereka merasa lebih tenang.

# %% [markdown]
# ## DISTRIBUSI SOCIAL WEAKNESS

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Social_Weakness", data=df, hue="Social_Weakness", legend=False, palette="muted")
plt.title("Kelemahan dalam Bersosialisasi")
plt.xlabel("Social Weakness")
plt.ylabel("Jumlah")
plt.show()

# %% [markdown]
# ### INSIGHT

# %% [markdown]
# Dari data yang ditampilkan, jumlah orang yang merasa memiliki kelemahan dalam bersosialisasi hampir setara dengan mereka yang merasa tidak mengalami kesulitan. Sementara itu, ada juga kelompok yang ragu-ragu atau berada di tengah-tengah.

# %% [markdown]
# ### TINDAKAN

# %% [markdown]
# Untuk membantu mereka yang merasa memiliki kelemahan dalam bersosialisasi, bisa dilakukan berbagai pendekatan seperti pelatihan keterampilan komunikasi, dukungan dari komunitas, atau kegiatan yang dapat meningkatkan kepercayaan diri dalam berinteraksi dengan orang lain.

# %% [markdown]
# ## DISTRIBUSI GENDER AND AGE

# %%
plt.figure(figsize=(7,7))
df["Gender_and_Age"].value_counts().plot.pie(autopct="%1.1f%%", cmap="viridis")
plt.title("Distribusi Gender dan Rentang Usia")
plt.ylabel("")
plt.show()

# %% [markdown]
# ### INSIGHT

# %% [markdown]
# Kelompok Female-30-Above memiliki persentase tertinggi sebesar 14.2%, diikuti oleh Female-25-30 dengan 14.0%. Sementara itu, kelompok dengan proporsi terendah adalah Male-25-30 sebesar 10.9%. Dari hasil ini, dapat disimpulkan bahwa data yang digunakan cukup seimbang antara laki-laki dan perempuan dengan distribusi usia yang bervariasi.

# %% [markdown]
# ## HUBUNGAN GROWING STRESS DENGAN OCCUPATION

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Growing_Stress'].value_counts()
    for x_label, grp in df.groupby('Occupation')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Occupation')
_ = plt.ylabel('Growing_Stress')

# %% [markdown]
# ### INSIGHT

# %% [markdown]
# Dari heatmap yang ditampilkan, terlihat bahwa tingkat stres yang meningkat banyak dialami oleh mahasiswa (Student), pekerja kantoran (Corporate), dan ibu rumah tangga (Housewife). Mahasiswa mungkin mengalami tekanan dari tuntutan akademik, jadwal yang padat, serta ketidakpastian masa depan. Pekerja kantoran berpotensi mengalami stres karena beban kerja yang tinggi, tekanan dari atasan, dan keseimbangan kehidupan kerja yang kurang optimal. Sementara itu, ibu rumah tangga bisa mengalami stres akibat tanggung jawab domestik yang besar serta kurangnya dukungan sosial yang memadai.

# %% [markdown]
# ### TINDAKAN

# %% [markdown]
#  Tindakan yang dapat diambil antara lain mahasiswa dapat diberikan akses lebih mudah ke layanan konseling kampus serta program manajemen waktu yang lebih baik. Perusahaan perlu mengadopsi kebijakan kesejahteraan karyawan, seperti fleksibilitas kerja dan program kesehatan mental untuk mengurangi stres pekerja kantoran. Sementara itu, bagi ibu rumah tangga, komunitas dukungan atau program berbasis masyarakat bisa dibentuk untuk memberikan bantuan serta ruang untuk berbagi pengalaman.

# %% [markdown]
# ## HUBUNGAN GROWING STRESS DENGAN QUARANTINE FRUSTRATIONS

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Quarantine_Frustrations'].value_counts()
    for x_label, grp in df.groupby('Growing_Stress')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Growing_Stress')
_ = plt.ylabel('Quarantine_Frustrations')

# %% [markdown]
# ### INSIGHT

# %% [markdown]
#  Terdapat korelasi yang cukup jelas antara frustrasi selama masa karantina dengan meningkatnya stres. Individu yang mengalami frustrasi selama karantina cenderung juga mengalami peningkatan stres, yang terlihat dari nilai tinggi di kategori "Yes" untuk kedua variabel tersebut. Sebaliknya, individu yang tidak merasa frustrasi selama karantina memiliki tingkat stres yang lebih rendah, yang ditunjukkan oleh intensitas warna yang lebih rendah pada bagian "No".

# %% [markdown]
# ### TINDAKAN

# %% [markdown]
# Tindakan yang dapat diambil untuk mengatasi permasalahan ini adalah dengan meningkatkan dukungan sosial dan akses terhadap aktivitas yang dapat mengurangi stres selama masa karantina. Program kesehatan mental seperti sesi terapi daring, kegiatan komunitas virtual, serta promosi gaya hidup sehat dapat membantu mengurangi frustrasi dan tekanan psikologis.
